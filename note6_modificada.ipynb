# %% [markdown]
# # Expresiones regulares
#
# Son un grupo de caracteres o patrones que se utilizan para encontrar una determinada combinación de caracteres dentro de una cadena de texto

# %% [markdown]
# Necesitamos usar un módulo llamado **re**

# %%
"""
El modulo re tiene varias funciones:
1. la función <sub> para realizar sustituciones
2. la función <findall> para hacer búsquedas
3. la función <finditer> para hacer búsquedas, pero además, devuelve las posiciones 
   de los elementos encontrados
"""
import re

# %%
s = 'tr|A0A2Z6TT02|A0A2Z6TT02_9LACO'

# %%
s
# Out:
# 'tr|A0A2Z6TT02|A0A2Z6TT02_9LACO'

# %%
re.sub('tr[|]|[|].*', '', s)
# Out:
# 'A0A2Z6TT02'

# %%
re.sub('tr[|]|[|].[*]', '', s)
# Out:
# 'A0A2Z6TT02|A0A2Z6TT02_9LACO'

# %%
re.sub('[|].*|[|]A0', '', s)
# Out:
# 'tr'

# %%
s1 = re.sub('tr[|]|[|].*', '', s)

# %%
s1
# Out:
# 'A0A2Z6TT02'

# %%
re.sub('sp[|]|[|].*', '', 'sp|Q99405|PRTM_ALKCK')
# Out:
# 'Q99405'

# %%
identificadores = ['tr|E0SC31|E0SC31_DICD3 Outer membrane exporter of proteases OS=Dickeya dadantii (strain 3937) OX=198628 GN=prtF PE=3 SV=1',
'sp|P23598|PRTF_DICCH Proteases secretion protein PrtF OS=Dickeya chrysanthemi OX=556 GN=prtF PE=3 SV=1',
'tr|A0A0A1HT80|A0A0A1HT80_9PSED ABC-type protease exporter, outer membrane component PrtF/AprF OS=Pseudomonas sp. SHC52 OX=984195 GN=BN844_0269 PE=3 SV=1',
'tr|A0A0C2IEA9|A0A0C2IEA9_9PSED ABC-type protease exporter, outer membrane component PrtF/AprF OS=Pseudomonas batumici OX=226910 GN=UCMB321_2798 PE=3 SV=1',
'tr|A0A0H3BX48|A0A0H3BX48_STRPZ Fibronectin binding protein OS=Streptococcus pyogenes serotype M49 (strain NZ131) OX=471876 GN=prtF PE=1 SV=1',
'tr|A0A0P9LC31|A0A0P9LC31_PSEA0 ABC-type protease exporter, outer membrane component PrtF/AprF OS=Pseudomonas amygdali pv. ciccaronei OX=264452 GN=ALO78_01561 PE=3 SV=1',
'tr|A0A0P9MT55|A0A0P9MT55_9PSED ABC-type protease exporter, outer membrane component PrtF/AprF OS=Pseudomonas caricapapayae OX=46678 GN=ALQ84_02418 PE=3 SV=1',
'tr|A0A0P9Q2D9|A0A0P9Q2D9_9PSED ABC transporter, permease protein OS=Pseudomonas syringae pv. delphinii OX=192088 GN=ALQ08_100846 PE=3 SV=1',
'tr|A0A0P9RGY3|A0A0P9RGY3_9PSED ABC-type protease exporter, outer membrane component PrtF/AprF OS=Pseudomonas ficuserectae OX=53410 GN=ALO69_100221 PE=3 SV=1',
'tr|A0A0P9SV80|A0A0P9SV80_PSESG ABC transporter permease OS=Pseudomonas savastanoi pv. glycinea OX=318 GN=ALO37_01686 PE=3 SV=1']

# %%
for i in identificadores:
    s1 = re.sub('^[s|t][p|r][|]|[|].*', '', i)
    print(s1)
# Out:
# E0SC31
# P23598
# #r
# -r
# ar
# xr
# A0A0P9MT55
# A0A0P9Q2D9
# wr
# /r

# %%
for i in identificadores:
    s1 = re.sub('^..[|]|[|].*', '', i)
    print(s1)
# Out:
# E0SC31
# P23598
# A0A0A1HT80
# A0A0C2IEA9
# A0A0H3BX48
# A0A0P9LC31
# A0A0P9MT55
# A0A0P9Q2D9
# A0A0P9RGY3
# A0A0P9SV80

# %%
for i in identificadores:
    s1 = re.sub('^..[|]|[|].*', '', i)
    print('https://www.uniprot.org/uniprotkb/'+s1+'/entry')
# Out:
# https://www.uniprot.org/uniprotkb/E0SC31/entry
# https://www.uniprot.org/uniprotkb/P23598/entry
# https://www.uniprot.org/uniprotkb/A0A0A1HT80/entry
# https://www.uniprot.org/uniprotkb/A0A0C2IEA9/entry
# https://www.uniprot.org/uniprotkb/A0A0H3BX48/entry
# https://www.uniprot.org/uniprotkb/A0A0P9LC31/entry
# https://www.uniprot.org/uniprotkb/A0A0P9MT55/entry
# https://www.uniprot.org/uniprotkb/A0A0P9Q2D9/entry
# https://www.uniprot.org/uniprotkb/A0A0P9RGY3/entry
# https://www.uniprot.org/uniprotkb/A0A0P9SV80/entry

# %%
identificadores[0]
# Out:
# 'tr|E0SC31|E0SC31_DICD3 Outer membrane exporter of proteases OS=Dickeya dadantii (strain 3937) OX=198628 GN=prtF PE=3 SV=1'

# %%
s2 = re.sub('^.*OS=', '', identificadores[0]).split(' ')

# %%
s2[0]+' '+s2[1]
# Out:
# 'Dickeya dadantii'

# %%
Dickeya dadantii

# %%
s3 = re.search('OS=\w+ \w+', identificadores[0]).group()

# %%
s3
# Out:
# 'OS=Dickeya dadantii'

# %%
re.sub('OS=', '', s3)
# Out:
# 'Dickeya dadantii'

# %%
for i in identificadores:
    s1 = re.sub('^..[|]|[|].*', '', i)
    s3 = re.search('OS=\w+ \w+', i).group()
    s4 = re.sub('OS=', '', s3)
    print(s1, s4)
# Out:
# E0SC31 Dickeya dadantii
# P23598 Dickeya chrysanthemi
# A0A0A1HT80 Pseudomonas sp
# A0A0C2IEA9 Pseudomonas batumici
# A0A0H3BX48 Streptococcus pyogenes
# A0A0P9LC31 Pseudomonas amygdali
# A0A0P9MT55 Pseudomonas caricapapayae
# A0A0P9Q2D9 Pseudomonas syringae
# A0A0P9RGY3 Pseudomonas ficuserectae
# A0A0P9SV80 Pseudomonas savastanoi

# %%
for i in identificadores:
    s1 = re.sub('^..[|]|[|].*', '', i)
    s2 = re.sub('^.*OS=', '', i).split(' ')
    s3 = s2[0]+' '+s2[1]
    print(s1, s3)
# Out:
# E0SC31 Dickeya dadantii
# P23598 Dickeya chrysanthemi
# A0A0A1HT80 Pseudomonas sp.
# A0A0C2IEA9 Pseudomonas batumici
# A0A0H3BX48 Streptococcus pyogenes
# A0A0P9LC31 Pseudomonas amygdali
# A0A0P9MT55 Pseudomonas caricapapayae
# A0A0P9Q2D9 Pseudomonas syringae
# A0A0P9RGY3 Pseudomonas ficuserectae
# A0A0P9SV80 Pseudomonas savastanoi

# %%
for i in identificadores:
    s1 = re.sub('^..[|]|[|].*', '', i)
    s2 = re.sub('^.*OS=', '', i).split(' ')
    s3 = s2[0]+' '+s2[1]
    print(s1 +'_'+ re.sub(' ', '_', s3))
# Out:
# E0SC31_Dickeya_dadantii
# P23598_Dickeya_chrysanthemi
# A0A0A1HT80_Pseudomonas_sp.
# A0A0C2IEA9_Pseudomonas_batumici
# A0A0H3BX48_Streptococcus_pyogenes
# A0A0P9LC31_Pseudomonas_amygdali
# A0A0P9MT55_Pseudomonas_caricapapayae
# A0A0P9Q2D9_Pseudomonas_syringae
# A0A0P9RGY3_Pseudomonas_ficuserectae
# A0A0P9SV80_Pseudomonas_savastanoi

# %% [markdown]
# # Continuaci[on de pandas

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### 1. abrir data frames

# %%
header = ['Entry', 'sacc', 'qlen', 'slen', 'length', 'score', 'bitscore', 'evalue', 'pident', 'nident', 'mismatch', 'positive', 'gaps', 'gapopen', 'stitle']

# %%
header
# Out:
# ['Entry',
#  'sacc',
#  'qlen',
#  'slen',
#  'length',
#  'score',
#  'bitscore',
#  'evalue',
#  'pident',
#  'nident',
#  'mismatch',
#  'positive',
#  'gaps',
#  'gapopen',
#  'stitle']

# %%
df = pd.read_csv('tabla.txt', sep = '\t', names = header)

# %%
df
# Out:
#                                   Entry           sacc  qlen  slen  length  \
# 0                tr|B2CJ54|B2CJ54_9HYPO  Bifido1_01605   401   892     257
# 1                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     780
# 2                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     210
# 3                  sp|S0DLN5|APF3_GIBF5  Bifido1_00708   295   266     276
# 4                 sp|S0DPY2|APF11_GIBF5  Bifido1_00712   562   683     325
# ...                                 ...            ...   ...   ...     ...
# 2024461  tr|A0A0L0LV25|A0A0L0LV25_BIFBR  Bifido1_00167   126   122     117
# 2024462  tr|A0A133KZQ8|A0A133KZQ8_BIFBR  Bifido1_00167   124   122     117
# 2024463  tr|A0A2K9AYJ9|A0A2K9AYJ9_BIFBR  Bifido1_00167   124   122     117
# 2024464          tr|V6XWB3|V6XWB3_BIFLN  Bifido1_00168   128   129     111
# 2024465          tr|W6EUJ5|W6EUJ5_BIFBR  Bifido1_00167   124   122     117
#
#          score  bitscore        evalue  pident  nident  mismatch  positive  \
# 0          143      59.7  7.690000e-11  27.237      70       163       114
# 1          880     343.0  7.790000e-97  31.282     244       469       370
# 2          270     108.0  1.500000e-24  34.762      73       126       102
# 3          142      59.3  2.090000e-11  26.087      72       177       120
# 4          197      80.5  5.120000e-17  22.769      74       220       141
# ...        ...       ...           ...     ...     ...       ...       ...
# 2024461    199      81.3  3.020000e-22  46.154      54        61        66
# 2024462    204      83.2  5.610000e-23  47.009      55        60        66
# 2024463    199      81.3  2.760000e-22  46.154      54        61        66
# 2024464    198      80.9  5.410000e-22  43.243      48        62        69
# 2024465    199      81.3  2.760000e-22  46.154      54        61        66
#
#          gaps  gapopen                                             stitle
# 0          24        7                                       Subtilisin E
# 1          67       16  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 2          11        2  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 3          27        7                  Pyrroline-5-carboxylate reductase
# 4          31        6                      Multidrug export protein EmrB
# ...       ...      ...                                                ...
# 2024461     2        1                               hypothetical protein
# 2024462     2        1                               hypothetical protein
# 2024463     2        1                               hypothetical protein
# 2024464     1        1                               hypothetical protein
# 2024465     2        1                               hypothetical protein
#
# [2024466 rows x 15 columns]

# %%
df2 = df.sort_values(by =['pident'], ascending = False).reset_index(drop = True)

# %%
df2
# Out:
#                                   Entry           sacc  qlen  slen  length  \
# 0                tr|C0BSD3|C0BSD3_9BIFI  Bifido1_01405   182   182     182
# 1        tr|A0A072N534|A0A072N534_9BIFI  Bifido1_01405   182   182     182
# 2        tr|A0A072MXX0|A0A072MXX0_9BIFI  Bifido1_01031   377   377     377
# 3                tr|B6XW67|B6XW67_9BIFI  Bifido1_01969   226   226     226
# 4                tr|C0BTI2|C0BTI2_9BIFI  Bifido1_01031   371   377     371
# ...                                 ...            ...   ...   ...     ...
# 2024461          tr|I3VUV3|I3VUV3_THESW  Bifido1_00196   370   345     289
# 2024462  tr|A0A378TG38|A0A378TG38_9MYCO  Bifido1_00476   313   288     252
# 2024463          tr|C7RI28|C7RI28_ANAPD  Bifido1_00125   538   655     538
# 2024464          tr|C7RI97|C7RI97_ANAPD  Bifido1_00655   348   609     354
# 2024465          tr|I3VUD6|I3VUD6_THESW  Bifido1_01639   231   241     208
#
#          score  bitscore         evalue   pident  nident  mismatch  positive  \
# 0          934     364.0  2.940000e-132  100.000     182         0       182
# 1          934     364.0  2.940000e-132  100.000     182         0       182
# 2         1975     765.0   0.000000e+00  100.000     377         0       377
# 3         1177     457.0  9.220000e-168  100.000     226         0       226
# 4         1941     752.0   0.000000e+00  100.000     371         0       371
# ...        ...       ...            ...      ...     ...       ...       ...
# 2024461    128      53.9   2.700000e-09   18.339      53       221       127
# 2024462     99      42.7   7.490000e-06   18.254      46       161       107
# 2024463    108      46.2   2.520000e-06   18.216      98       361       212
# 2024464    150      62.4   7.990000e-12   18.079      64       208       147
# 2024465    102      43.9   1.510000e-06   15.865      33       169        91
#
#          gaps  gapopen                                             stitle
# 0           0        0                       Lipoprotein signal peptidase
# 1           0        0                       Lipoprotein signal peptidase
# 2           0        0        Heat-inducible transcription repressor HrcA
# 3           0        0                                       Protein GrpE
# 4           0        0        Heat-inducible transcription repressor HrcA
# ...       ...      ...                                                ...
# 2024461    15        5                            Ribose operon repressor
# 2024462    45        5  Inner membrane ABC transporter permease protei...
# 2024463    79       16       putative ABC transporter ATP-binding protein
# 2024464    82       11              putative sensor histidine kinase TcrY
# 2024465     6        4  CRP-like cAMP-activated global transcriptional...
#
# [2024466 rows x 15 columns]

# %%
df2[df2.pident >= 70]
# Out:
#                                Entry           sacc  qlen  slen  length  \
# 0             tr|C0BSD3|C0BSD3_9BIFI  Bifido1_01405   182   182     182
# 1     tr|A0A072N534|A0A072N534_9BIFI  Bifido1_01405   182   182     182
# 2     tr|A0A072MXX0|A0A072MXX0_9BIFI  Bifido1_01031   377   377     377
# 3             tr|B6XW67|B6XW67_9BIFI  Bifido1_01969   226   226     226
# 4             tr|C0BTI2|C0BTI2_9BIFI  Bifido1_01031   371   377     371
# ...                              ...            ...   ...   ...     ...
# 1077  tr|A0A3D0PZ99|A0A3D0PZ99_9BIFI  Bifido1_00168   130   129     110
# 1078  tr|A0A261G7D8|A0A261G7D8_9BIFI  Bifido1_01405   206   182     190
# 1079  tr|A0A7X9BHE6|A0A7X9BHE6_9BIFI  Bifido1_01969    76   226      20
# 1080  tr|A0A5J5E9U6|A0A5J5E9U6_9BIFI  Bifido1_01969   250   226     250
# 1081  tr|A0A836WLE1|A0A836WLE1_9AQUI  Bifido1_01968   386   343      70
#
#       score  bitscore         evalue  pident  nident  mismatch  positive  \
# 0       934     364.0  2.940000e-132   100.0     182         0       182
# 1       934     364.0  2.940000e-132   100.0     182         0       182
# 2      1975     765.0   0.000000e+00   100.0     377         0       377
# 3      1177     457.0  9.220000e-168   100.0     226         0       226
# 4      1941     752.0   0.000000e+00   100.0     371         0       371
# ...     ...       ...            ...     ...     ...       ...       ...
# 1077    374     148.0   1.640000e-48    70.0      77        33        92
# 1078    676     265.0   1.560000e-92    70.0     133        49       155
# 1079     86      37.7   7.480000e-06    70.0      14         6        18
# 1080    802     313.0  2.370000e-110    70.0     175        50       191
# 1081    240      97.1   1.040000e-23    70.0      49        17        58
#
#       gaps  gapopen                                       stitle
# 0        0        0                 Lipoprotein signal peptidase
# 1        0        0                 Lipoprotein signal peptidase
# 2        0        0  Heat-inducible transcription repressor HrcA
# 3        0        0                                 Protein GrpE
# 4        0        0  Heat-inducible transcription repressor HrcA
# ...    ...      ...                                          ...
# 1077     0        0                         hypothetical protein
# 1078     8        1                 Lipoprotein signal peptidase
# 1079     0        0                                 Protein GrpE
# 1080    25        4                                 Protein GrpE
# 1081     4        2                   Curved DNA-binding protein
#
# [1082 rows x 15 columns]

# %%
# espec[ifica]
df2[df2.Entry == 'tr|C7RI97|C7RI97_ANAPD']
# Out:
#                           Entry           sacc  qlen  slen  length  score  \
# 2004273  tr|C7RI97|C7RI97_ANAPD  Bifido1_00429   348   399     123    105
# 2020040  tr|C7RI97|C7RI97_ANAPD  Bifido1_00781   348   379     231    200
# 2023174  tr|C7RI97|C7RI97_ANAPD  Bifido1_00308   348   461     230    159
# 2023442  tr|C7RI97|C7RI97_ANAPD  Bifido1_00677   348   527     217    168
# 2024464  tr|C7RI97|C7RI97_ANAPD  Bifido1_00655   348   609     354    150
#
#          bitscore        evalue  pident  nident  mismatch  positive  gaps  \
# 2004273      45.1  2.090000e-06  22.764      28        93        57     2
# 2020040      81.6  1.970000e-18  21.645      50       176       111     5
# 2023174      65.9  4.720000e-13  20.870      48       158       111    24
# 2023442      69.3  3.210000e-14  20.737      45       170       106     2
# 2024464      62.4  7.990000e-12  18.079      64       208       147    82
#
#          gapopen                                             stitle
# 2004273        1         Signal-transduction histidine kinase senX3
# 2020040        2  Signal transduction histidine-protein kinase BaeS
# 2023174        4         Signal-transduction histidine kinase senX3
# 2023442        2                       Sensor histidine kinase MtrB
# 2024464       11              putative sensor histidine kinase TcrY

# %%
# b[usqueda de patrones
df[df.Entry.str.contains('C7RI97') == True]
# Out:
#                        Entry           sacc  qlen  slen  length  score  \
# 5600  tr|C7RI97|C7RI97_ANAPD  Bifido1_00781   348   379     231    200
# 5601  tr|C7RI97|C7RI97_ANAPD  Bifido1_00677   348   527     217    168
# 5602  tr|C7RI97|C7RI97_ANAPD  Bifido1_00308   348   461     230    159
# 5603  tr|C7RI97|C7RI97_ANAPD  Bifido1_00655   348   609     354    150
# 5604  tr|C7RI97|C7RI97_ANAPD  Bifido1_00429   348   399     123    105
#
#       bitscore        evalue  pident  nident  mismatch  positive  gaps  \
# 5600      81.6  1.970000e-18  21.645      50       176       111     5
# 5601      69.3  3.210000e-14  20.737      45       170       106     2
# 5602      65.9  4.720000e-13  20.870      48       158       111    24
# 5603      62.4  7.990000e-12  18.079      64       208       147    82
# 5604      45.1  2.090000e-06  22.764      28        93        57     2
#
#       gapopen                                             stitle
# 5600        2  Signal transduction histidine-protein kinase BaeS
# 5601        2                       Sensor histidine kinase MtrB
# 5602        4         Signal-transduction histidine kinase senX3
# 5603       11              putative sensor histidine kinase TcrY
# 5604        1         Signal-transduction histidine kinase senX3

# %%
df[df.stitle.str.contains('ABC') == True]
# Out:
#                           Entry           sacc  qlen  slen  length  score  \
# 91       tr|C7RE16|C7RE16_ANAPD  Bifido1_01015   935   995     943   2928
# 92       tr|C7RE16|C7RE16_ANAPD  Bifido1_01015   935   995     140    168
# 93       tr|C7RE16|C7RE16_ANAPD  Bifido1_00862   935   838     697    972
# 94       tr|C7RE16|C7RE16_ANAPD  Bifido1_00862   935   838     147    271
# 95       tr|C7RE16|C7RE16_ANAPD  Bifido1_00862   935   838     189    263
# ...                         ...            ...   ...   ...     ...    ...
# 2022707  tr|I3VYQ5|I3VYQ5_THESW  Bifido1_00671   220   225     149    212
# 2022708  tr|I3VYQ5|I3VYQ5_THESW  Bifido1_00573   220   224     207    137
# 2022712  tr|I3VYQ6|I3VYQ6_THESW  Bifido1_00575   258   302     236    241
# 2022713  tr|I3VYQ6|I3VYQ6_THESW  Bifido1_00670   258   279     256    199
# 2022715  tr|I3VYQ6|I3VYQ6_THESW  Bifido1_00931   258   288     262    136
#
#          bitscore         evalue  pident  nident  mismatch  positive  gaps  \
# 91         1132.0   0.000000e+00  59.279     559       374       712    10
# 92           69.3   4.730000e-13  32.857      46        76        74    18
# 93          379.0  9.330000e-119  33.716     235       409       378    53
# 94          108.0   2.260000e-25  36.054      53        82        87    12
# 95          105.0   1.770000e-24  34.921      66       114       106     9
# ...           ...            ...     ...     ...       ...       ...   ...
# 2022707      86.3   5.480000e-22  31.544      47        95        81     7
# 2022708      57.4   2.520000e-11  23.671      49       146       102    12
# 2022712      97.4   4.440000e-25  30.932      73       153       124    10
# 2022713      81.3   2.130000e-19  27.734      71       167       117    18
# 2022715      57.0   9.160000e-11  23.664      62       183       117    17
#
#          gapopen                                             stitle
# 91             4                            UvrABC system protein A
# 92             4                            UvrABC system protein A
# 93            11                            UvrABC system protein A
# 94             1                            UvrABC system protein A
# 95             2                            UvrABC system protein A
# ...          ...                                                ...
# 2022707        2  putative glutamine ABC transporter permease pr...
# 2022708        5  putative glutamine ABC transporter permease pr...
# 2022712        5     ABC transporter glutamine-binding protein GlnH
# 2022713        6     ABC transporter glutamine-binding protein GlnH
# 2022715        8     ABC transporter glutamine-binding protein GlnH
#
# [470637 rows x 15 columns]

# %%
df
# Out:
#                                   Entry           sacc  qlen  slen  length  \
# 0                tr|B2CJ54|B2CJ54_9HYPO  Bifido1_01605   401   892     257
# 1                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     780
# 2                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     210
# 3                  sp|S0DLN5|APF3_GIBF5  Bifido1_00708   295   266     276
# 4                 sp|S0DPY2|APF11_GIBF5  Bifido1_00712   562   683     325
# ...                                 ...            ...   ...   ...     ...
# 2024461  tr|A0A0L0LV25|A0A0L0LV25_BIFBR  Bifido1_00167   126   122     117
# 2024462  tr|A0A133KZQ8|A0A133KZQ8_BIFBR  Bifido1_00167   124   122     117
# 2024463  tr|A0A2K9AYJ9|A0A2K9AYJ9_BIFBR  Bifido1_00167   124   122     117
# 2024464          tr|V6XWB3|V6XWB3_BIFLN  Bifido1_00168   128   129     111
# 2024465          tr|W6EUJ5|W6EUJ5_BIFBR  Bifido1_00167   124   122     117
#
#          score  bitscore        evalue  pident  nident  mismatch  positive  \
# 0          143      59.7  7.690000e-11  27.237      70       163       114
# 1          880     343.0  7.790000e-97  31.282     244       469       370
# 2          270     108.0  1.500000e-24  34.762      73       126       102
# 3          142      59.3  2.090000e-11  26.087      72       177       120
# 4          197      80.5  5.120000e-17  22.769      74       220       141
# ...        ...       ...           ...     ...     ...       ...       ...
# 2024461    199      81.3  3.020000e-22  46.154      54        61        66
# 2024462    204      83.2  5.610000e-23  47.009      55        60        66
# 2024463    199      81.3  2.760000e-22  46.154      54        61        66
# 2024464    198      80.9  5.410000e-22  43.243      48        62        69
# 2024465    199      81.3  2.760000e-22  46.154      54        61        66
#
#          gaps  gapopen                                             stitle
# 0          24        7                                       Subtilisin E
# 1          67       16  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 2          11        2  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 3          27        7                  Pyrroline-5-carboxylate reductase
# 4          31        6                      Multidrug export protein EmrB
# ...       ...      ...                                                ...
# 2024461     2        1                               hypothetical protein
# 2024462     2        1                               hypothetical protein
# 2024463     2        1                               hypothetical protein
# 2024464     1        1                               hypothetical protein
# 2024465     2        1                               hypothetical protein
#
# [2024466 rows x 15 columns]

# %%
entry_nueva = []
for i in df.Entry:
    s1 = re.sub('^..[|]|[|].*', '', i)
    entry_nueva.append(s1)

# %%
entry_nueva
# Out:
# ['B2CJ54',
#  'S0DL59',
#  'S0DL59',
#  'S0DLN5',
#  'S0DPY2',
#  'S0DPY2',
#  'S0DPY2',
#  'S0DPY2',
#  'S0DPY2',
#  'S0DS11',
#  'A0A2Z6TT02',
#  'A0A3G2M2M4',
#  'A0A3G2M2M4',
#  'A0A3G2M2P2',
#  'A0A3G2M2P2',
#  'A0A3G2M2Q4',
#  'A0A3G2M2Q4',
#  'A0A3G2M2Q8',
#  'A0A3G2M2Q8',
#  'A0A3G2M2Q9',
#  'A0A3G2M2Q9',
#  'A0A3G2M2R3',
#  'A0A3G2M2R3',
#  'A0A3G2M2S3',
#  'A0A3G2M2S3',
#  'A0A3G2M2S4',
#  'A0A3G2M2S4',
#  'A0A3G2M2S6',
#  'A0A3G2M2S6',
#  'A0A3G2M2S7',
#  'A0A3G2M2S7',
#  'A0A3G2M2T1',
#  'A0A3G2M2T1',
#  'A0A3G2M2T7',
#  'A0A3G2M2T7',
#  'A0A3G2M2U4',
#  'A0A3G2M2U4',
#  'E0F462',
#  'E0F462',
#  'E0F463',
#  'E0F463',
#  'Q5W5V4',
#  'P04189',
#  'P04189',
#  'Q99405',
#  'C7REX2',
#  'C7REX2',
#  'C7REX2',
#  'C7REX2',
#  'C7RGU3',
#  'C7RHG5',
#  'C7RHM7',
#  'C7RHN6',
#  'C7RHN6',
#  'C7RHN7',
#  'P50863',
#  'P50863',
#  'C7RD70',
#  'C7RD70',
#  'C7RD71',
#  'C7RD71',
#  'C7RD74',
#  'C7RD74',
#  'C7RD78',
#  'C7RDC4',
#  'C7RDC8',
#  'C7RDC8',
#  'C7RDC8',
#  'C7RDC9',
#  'C7RDG2',
#  'C7RDG4',
#  'C7RDG5',
#  'C7RDG5',
#  'C7RDG5',
#  'C7RDG6',
#  'C7RDG6',
#  'C7RDJ3',
#  'C7RDJ3',
#  'C7RDK2',
#  'C7RDK2',
#  'C7RDK2',
#  'C7RDK2',
#  'C7RDK8',
#  'C7RDL0',
#  'C7RDN8',
#  'C7RDP9',
#  'C7RDP9',
#  'C7RDP9',
#  'C7RDP9',
#  'C7RDU9',
#  'C7RDV0',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE16',
#  'C7RE17',
#  'C7RE17',
#  'C7RE26',
#  'C7RE78',
#  'C7RE78',
#  'C7RE78',
#  'C7RE78',
#  'C7RE78',
#  'C7RE78',
#  'C7RE78',
#  'C7RE86',
#  'C7REA8',
#  'C7REB4',
#  'C7REB4',
#  'C7REB4',
#  'C7REB7',
#  'C7REC0',
#  'C7REC2',
#  'C7REF5',
#  'C7REG1',
#  'C7REN0',
#  'C7REN0',
#  'C7REN6',
#  'C7REN6',
#  'C7REN7',
#  'C7REQ3',
#  'C7REQ4',
#  'C7REQ4',
#  'C7RER6',
#  'C7RES2',
#  'C7REY8',
#  'C7REY8',
#  'C7REY8',
#  'C7REZ9',
#  'C7REZ9',
#  'C7REZ9',
#  'C7RF00',
#  'C7RF00',
#  'C7RF15',
#  'C7RF15',
#  'C7RF43',
#  'C7RFG7',
#  'C7RFG8',
#  'C7RFH0',
#  'C7RFH0',
#  'C7RFH0',
#  'C7RFH6',
#  'C7RFH6',
#  'C7RFL5',
#  'C7RFL5',
#  'C7RFM5',
#  'C7RFS0',
#  'C7RFS4',
#  'C7RFS4',
#  'C7RFS4',
#  'C7RFS4',
#  'C7RFS4',
#  'C7RFT1',
#  'C7RFX0',
#  'C7RFX7',
#  'C7RFX7',
#  'C7RG11',
#  'C7RG18',
#  'C7RG72',
#  'C7RG72',
#  'C7RG73',
#  'C7RG82',
#  'C7RG82',
#  'C7RG83',
#  'C7RG83',
#  'C7RGC3',
#  'C7RGC7',
#  'C7RGD0',
#  'C7RGL1',
#  'C7RGP4',
#  'C7RGP6',
#  'C7RGP6',
#  'C7RGP6',
#  'C7RGP9',
#  'C7RGQ0',
#  'C7RGQ6',
#  'C7RGS4',
#  'C7RGT3',
#  'C7RGT7',
#  'C7RGU7',
#  'C7RGU9',
#  'C7RH17',
#  'C7RH17',
#  'C7RH19',
#  'C7RH19',
#  'C7RH23',
#  'C7RH24',
#  'C7RH28',
#  'C7RH28',
#  'C7RH33',
#  'C7RH34',
#  'C7RH35',
#  'C7RH52',
#  'C7RH52',
#  'C7RH53',
#  'C7RHD5',
#  'C7RHD5',
#  'C7RHE4',
#  'C7RHF0',
#  'C7RHH2',
#  'C7RHH2',
#  'C7RHH2',
#  'C7RHH4',
#  'C7RHH8',
#  'C7RHH8',
#  'C7RHI0',
#  'C7RHI0',
#  'C7RHI0',
#  'C7RHI2',
#  'C7RHI5',
#  'C7RHI8',
#  'C7RHK3',
#  'C7RHL7',
#  'C7RHM6',
#  'C7RHM6',
#  'C7RHP0',
#  'C7RHP0',
#  'C7RHP3',
#  'C7RHP8',
#  'C7RHP8',
#  'C7RHQ1',
#  'C7RHQ2',
#  'C7RHS1',
#  'C7RHT5',
#  'C7RHT6',
#  'C7RHT6',
#  'C7RHT6',
#  'C7RHT6',
#  'C7RHV4',
#  'C7RHW5',
#  'C7RHY1',
#  'C7RHY1',
#  'C7RHY7',
#  'A0A117EDA3',
#  'A0A117EDA3',
#  'A0A174CE76',
#  'A0A174CE76',
#  'A0A1A9GI02',
#  'A0A1B9EYZ9',
#  'A0A1C5SLV1',
#  'A0A1C6H524',
#  'A0A1K2G1S3',
#  'A0A1K2G1S3',
#  'A0A1V6CME3',
#  'A0A2I4SBV7',
#  'A0A2I4SBV7',
#  'A0A2I4SZS9',
#  'A0A2I4SZS9',
#  'A0A2Z5K950',
#  'A0A399GHH2',
#  'A0A399GHH2',
#  'A0A3G6J7P0',
#  'A0A3G9HGV7',
#  'A0A3G9HGV7',
#  'A0A498TTE1',
#  'A0A498TTE1',
#  'A0A5B9T6U5',
#  'A0A5B9T6U5',
#  'A0A5D4N1I4',
#  'A0A5D4N1I4',
#  'A0A5P2ZRR0',
#  'A0A653NQW7',
#  'A0A653NQW7',
#  'A0A6A8FTL4',
#  'A0A6A8FTL4',
#  'A0A6C0Q9A4',
#  'A0A6H0H138',
#  'A0A6H0H138',
#  'A0A6H0WGG1',
#  'A0A6H0WGG1',
#  'A0A6H2JNR9',
#  'A0A6H2JNR9',
#  'A0A6M4JK64',
#  'A0A6M4JK64',
#  'A0A7G7UAN6',
#  'A0A7G7UAN6',
#  'A0A7M4DS82',
#  'A0A8B4QAM2',
#  'A0A8D6A026',
#  'A0A8D6A026',
#  'A0A8F7SQY3',
#  'A0A8F7SQY3',
#  'A0A8G0WGZ3',
#  'A0A8G0WGZ3',
#  'A0FLP4',
#  'A0FLP4',
#  'C7RD66',
#  'C7RD66',
#  'C7RD66',
#  'C7RD67',
#  'C7RD68',
#  'C7RD69',
#  'C7RD72',
#  'C7RD75',
#  'C7RD91',
#  'C7RD92',
#  'C7RD98',
#  'C7RD99',
#  'C7RDA3',
#  'C7RDA3',
#  'C7RDA3',
#  'C7RDA3',
#  'C7RDA3',
#  'C7RDA3',
#  'C7RDA7',
#  'C7RDA8',
#  'C7RDA9',
#  'C7RDB0',
#  'C7RDB1',
#  'C7RDB5',
#  'C7RDB5',
#  'C7RDB8',
#  'C7RDD0',
#  'C7RDD1',
#  'C7RDD3',
#  'C7RDD9',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE4',
#  'C7RDE5',
#  'C7RDE6',
#  'C7RDF8',
#  'C7RDF8',
#  'C7RDF8',
#  'C7RDF8',
#  'C7RDF8',
#  'C7RDF8',
#  'C7RDF9',
#  'C7RDF9',
#  'C7RDG1',
#  'C7RDG8',
#  'C7RDG9',
#  'C7RDH0',
#  'C7RDH1',
#  'C7RDH3',
#  'C7RDH4',
#  'C7RDH4',
#  'C7RDH4',
#  'C7RDH4',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ0',
#  'C7RDJ6',
#  'C7RDK4',
#  'C7RDK9',
#  'C7RDK9',
#  'C7RDL4',
#  'C7RDL7',
#  'C7RDP0',
#  'C7RDP0',
#  'C7RDP0',
#  'C7RDP0',
#  'C7RDP0',
#  'C7RDP0',
#  'C7RDP8',
#  'C7RDQ2',
#  'C7RDQ3',
#  'C7RDQ9',
#  'C7RDR0',
#  'C7RDR4',
#  'C7RDR4',
#  'C7RDS5',
#  'C7RDS5',
#  'C7RDS8',
#  'C7RDT9',
#  'C7RDU0',
#  'C7RDU5',
#  'C7RDV2',
#  'C7RDV4',
#  'C7RDV8',
#  'C7RDW2',
#  'C7RDX3',
#  'C7RDY0',
#  'C7RDY7',
#  'C7RDY7',
#  'C7RDY7',
#  'C7RDY8',
#  'C7RDY8',
#  'C7RE04',
#  'C7RE05',
#  'C7RE14',
#  'C7RE20',
#  'C7RE20',
#  'C7RE20',
#  'C7RE20',
#  'C7RE20',
#  'C7RE20',
#  'C7RE23',
#  'C7RE23',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE28',
#  'C7RE62',
#  'C7RE62',
#  'C7REA4',
#  'C7REA4',
#  'C7REA4',
#  'C7REA4',
#  'C7REA9',
#  'C7RED3',
#  'C7REE8',
#  'C7REF4',
#  'C7REF6',
#  'C7REF7',
#  'C7REF8',
#  'C7REG0',
#  'C7REG2',
#  'C7REG3',
#  'C7REG4',
#  'C7REG5',
#  'C7REG6',
#  'C7REG7',
#  'C7REG8',
#  'C7REG9',
#  'C7REH0',
#  'C7REH1',
#  'C7REH2',
#  'C7REH3',
#  'C7REH5',
#  'C7REH6',
#  'C7REH7',
#  'C7REH8',
#  'C7REH9',
#  'C7REI0',
#  'C7REI1',
#  'C7REI2',
#  'C7REI3',
#  'C7REM4',
#  'C7REM4',
#  'C7REM5',
#  'C7REN4',
#  'C7REN4',
#  'C7REP0',
#  'C7REP5',
#  'C7RES9',
#  'C7RES9',
#  'C7RES9',
#  'C7REU2',
#  'C7REU2',
#  'C7REU3',
#  'C7REU3',
#  'C7REV3',
#  'C7REV7',
#  'C7REV7',
#  'C7REY6',
#  'C7REZ5',
#  'C7REZ6',
#  'C7REZ8',
#  'C7RF11',
#  'C7RF11',
#  'C7RF11',
#  'C7RF11',
#  'C7RF11',
#  'C7RF25',
#  'C7RF25',
#  'C7RF41',
#  'C7RF41',
#  'C7RF41',
#  'C7RF42',
#  'C7RF65',
#  'C7RF65',
#  'C7RF69',
#  'C7RF75',
#  'C7RF89',
#  'C7RF90',
#  'C7RF97',
#  'C7RFC6',
#  'C7RFC7',
#  'C7RFC9',
#  'C7RFE6',
#  'C7RFG6',
#  'C7RFG9',
#  'C7RFH2',
#  'C7RFH5',
#  'C7RFH5',
#  'C7RFH9',
#  'C7RFJ6',
#  'C7RFJ6',
#  'C7RFJ6',
#  'C7RFJ6',
#  'C7RFM8',
#  'C7RFM8',
#  'C7RFU7',
#  'C7RFX2',
#  'C7RFX2',
#  'C7RFX2',
#  'C7RFX2',
#  'C7RFX3',
#  'C7RG12',
#  'C7RG12',
#  'C7RG13',
#  'C7RG13',
#  'C7RG16',
#  'C7RG20',
#  'C7RG48',
#  'C7RG51',
#  'C7RG51',
#  'C7RG52',
#  'C7RG77',
#  'C7RG89',
#  'C7RG93',
#  'C7RG94',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RG95',
#  'C7RGA9',
#  'C7RGB9',
#  'C7RGC0',
#  'C7RGC0',
#  'C7RGC1',
#  'C7RGC4',
#  'C7RGC4',
#  'C7RGC8',
#  'C7RGE3',
#  'C7RGF9',
#  'C7RGF9',
#  'C7RGF9',
#  'C7RGF9',
#  'C7RGF9',
#  'C7RGG9',
#  'C7RGH0',
#  'C7RGH6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGJ6',
#  'C7RGL4',
#  'C7RGL6',
#  'C7RGL6',
#  'C7RGM5',
#  'C7RGM6',
#  'C7RGM8',
#  'C7RGM9',
#  'C7RGM9',
#  'C7RGM9',
#  'C7RGM9',
#  'C7RGN8',
#  'C7RGP0',
#  'C7RGP0',
#  'C7RGP0',
#  'C7RGP0',
#  'C7RGP0',
#  'C7RGP0',
#  'C7RGP1',
#  'C7RGP3',
#  'C7RGP5',
#  'C7RGP7',
#  'C7RGP7',
#  'C7RGP7',
#  'C7RGP8',
#  'C7RGP8',
#  'C7RGQ3',
#  'C7RGQ4',
#  'C7RGQ7',
#  'C7RGQ8',
#  'C7RGQ9',
#  'C7RGQ9',
#  'C7RGQ9',
#  'C7RGS5',
#  'C7RGU0',
#  'C7RGU0',
#  'C7RGU0',
#  'C7RGU1',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGU5',
#  'C7RGV2',
#  'C7RGV3',
#  'C7RGV5',
#  'C7RGW0',
#  'C7RH15',
#  'C7RH16',
#  'C7RH18',
#  'C7RH20',
#  'C7RH20',
#  'C7RH22',
#  'C7RH25',
#  'C7RH30',
#  'C7RH31',
#  'C7RH31',
#  'C7RH32',
#  'C7RH38',
#  'C7RH47',
#  'C7RH47',
#  'C7RH48',
#  'C7RH50',
#  'C7RH50',
#  'C7RH55',
#  'C7RH57',
#  'C7RH57',
#  'C7RH57',
#  'C7RH59',
#  'C7RH61',
#  'C7RHD8',
#  'C7RHG0',
#  'C7RHG3',
#  'C7RHG3',
#  'C7RHG3',
#  'C7RHG3',
#  'C7RHG3',
#  'C7RHH0',
#  'C7RHH1',
#  'C7RHH7',
#  'C7RHH7',
#  'C7RHI3',
#  'C7RHI3',
#  'C7RHI3',
#  'C7RHI6',
#  'C7RHI9',
#  'C7RHJ1',
#  'C7RHJ3',
#  'C7RHJ5',
#  'C7RHJ6',
#  'C7RHJ6',
#  'C7RHJ8',
#  'C7RHK0',
#  'C7RHK5',
#  'C7RHK8',
#  'C7RHM1',
#  'C7RHM1',
#  'C7RHM1',
#  'C7RHM1',
#  'C7RHM1',
#  'C7RHM3',
#  'C7RHM3',
#  'C7RHM4',
#  'C7RHM5',
#  'C7RHM5',
#  'C7RHM9',
#  'C7RHN4',
#  'C7RHN4',
#  'C7RHN4',
#  'C7RHN4',
#  'C7RHN4',
#  'C7RHN5',
#  'C7RHP2',
#  'C7RHP5',
#  'C7RHP6',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHP9',
#  'C7RHQ4',
#  'C7RHQ4',
#  'C7RHQ4',
#  'C7RHQ4',
#  'C7RHQ4',
#  'C7RHQ4',
#  'C7RHR7',
#  'C7RHR7',
#  'C7RHR9',
#  'C7RHR9',
#  'C7RHS7',
#  'C7RHS7',
#  'C7RHS8',
#  'C7RHS8',
#  'C7RHS8',
#  'C7RHT7',
#  'C7RHT7',
#  'C7RHT8',
#  'C7RHU4',
#  'C7RHU5',
#  'C7RHU8',
#  'C7RHV1',
#  'C7RHW1',
#  'C7RHW3',
#  'C7RHW3',
#  'C7RHW7',
#  'C7RHW7',
#  'C7RHW7',
#  'C7RHW7',
#  'C7RHX1',
#  'C7RHX8',
#  'C7RI86',
#  'C7RI86',
#  'C7RI86',
#  'D4PBI3',
#  'D4PBI3',
#  'E0TYP4',
#  'E0TYP4',
#  'E3WEB7',
#  'E3WEB7',
#  'F7V004',
#  'F7V004',
#  'I2C387',
#  'I2C387',
#  'M4KWV6',
#  'M4KWV6',
#  'M5AJZ8',
#  'M5AJZ8',
#  'M5AKX0',
#  'M5AKX0',
#  'M5B284',
#  'M5B284',
#  'Q1EM64',
#  'Q1EM64',
#  'Q58LV1',
#  'Q58LV1',
#  'Q84F18',
#  'Q84F18',
#  'S6FQM8',
#  'S6FQM8',
#  'X2J502',
#  'X2J502',
#  'A0A031IB93',
#  'A0A068NFD5',
#  'A0A076MVQ0',
#  'A0A0A8WWX9',
#  'A0A0C6EZ02',
#  'A0A0C6FEK6',
#  'A0A0E3WJM8',
#  'A0A0H3CVJ8',
#  'A0A0H3DFK8',
#  'A0A0M2H4F9',
#  'A0A0M9ACN6',
#  'A0A0P9FW33',
#  'A0A0U5C9B2',
#  'A0A0U5C9B2',
#  'A0A100J1Q8',
#  'A0A100JCI4',
#  'A0A100JM72',
#  'A0A100JM72',
#  'A0A132BYR8',
#  'A0A136BZS9',
#  'A0A151AWC9',
#  'A0A151AWC9',
#  'A0A161PXE5',
#  'A0A164TMF8',
#  'A0A164TMF8',
#  'A0A165A2Z2',
#  'A0A165A2Z2',
#  'A0A1A7KFT1',
#  'A0A1C3F8Q3',
#  'A0A1C9W8E9',
#  'A0A1J5JWL2',
#  'A0A1J5JWL2',
#  'A0A1J5NIH2',
#  'A0A1J5NIH2',
#  'A0A1K1YQR7',
#  'A0A1L3LC67',
#  'A0A1L3LZL3',
#  'A0A1Q2Z4M6',
#  'A0A1Q2ZJ82',
#  'A0A1V1RHN9',
#  'A0A1V4WKW6',
#  'A0A1V5C1P4',
#  'A0A1V5CTP4',
#  'A0A1V5DP96',
#  'A0A1V5DP96',
#  'A0A1V5G1Y0',
#  'A0A1V5LIF3',
#  'A0A251XW32',
#  'A0A251XW32',
#  'A0A251YVC8',
#  'A0A251YVC8',
#  'A0A251YVI4',
#  'A0A251YVI4',
#  'A0A284VME1',
#  'A0A2H6A8J9',
#  'A0A2H6G313',
#  'A0A2I7M8J7',
#  'A0A2I7M8J7',
#  'A0A2N9B9Z7',
#  'A0A2N9B9Z7',
#  'A0A2P7ZCD2',
#  'A0A2P7ZCD2',
#  'A0A2P8AEG8',
#  'A0A2P8AEG8',
#  'A0A2P8AEI8',
#  'A0A2P8AEI8',
#  'A0A2T0ALS8',
#  'A0A2T0ALS8',
#  'A0A2X0U259',
#  'A0A2X0U259',
#  'A0A2X2M2X7',
#  'A0A2Z2NVI6',
#  'A0A2Z5SHR4',
#  'A0A343TG46',
#  'A0A378XE28',
#  'A0A379LXI0',
#  'A0A381F8I8',
#  'A0A381FIX7',
#  'A0A385ZP45',
#  'A0A385ZP45',
#  'A0A386A0J8',
#  'A0A386A0J8',
#  'A0A399EFH9',
#  'A0A399EQQ2',
#  'A0A399EQQ2',
#  'A0A399F4Z3',
#  'A0A399F755',
#  'A0A3G6IVZ5',
#  'A0A3G6IVZ5',
#  'A0A3T0KRJ6',
#  'A0A448CFY6',
#  'A0A4D4J4M0',
#  'A0A4R8QU11',
#  'A0A4R8QU11',
#  'A0A4V3HR57',
#  'A0A4V3HR57',
#  'A0A511W5E1',
#  'A0A511W5E1',
#  'A0A511W5E6',
#  'A0A511W5F1',
#  'A0A511WMP8',
#  'A0A511WMP8',
#  'A0A517M8I5',
#  'A0A517MKF5',
#  'A0A517MY95',
#  'A0A517N451',
#  'A0A517TMV1',
#  'A0A517YE72',
#  'A0A518D7G3',
#  'A0A518DAY8',
#  'A0A518HN97',
#  'A0A518IU14',
#  'A0A518K1A3',
#  'A0A564G3U9',
#  'A0A564G3U9',
#  'A0A5A5R7V7',
#  'A0A5A5R7V7',
#  'A0A5B9P7L6',
#  'A0A5B9QGD8',
#  'A0A5C5V7G2',
#  'A0A5C5YB12',
#  'A0A5C5YS43',
#  'A0A5C6FLS4',
#  'A0A5D3IAX7',
#  'A0A5D3IAX7',
#  'A0A5J4E1T0',
#  'A0A5P9CGQ2',
#  'A0A5P9CGQ2',
#  'A0A649YM37',
#  'A0A649YM37',
#  'A0A6B8N5D7',
#  'A0A6B8N5D7',
#  'A0A6I5ZNC8',
#  'A0A6I5ZNC8',
#  'A0A6I6MJY3',
#  'A0A6I7TXG9',
#  'A0A6N2T0M0',
#  'A0A6S6WRC2',
#  'A0A6S6WRC2',
#  'A0A6V7R954',
#  'A0A853W3J5',
#  'A0A853W3J5',
#  'A0A897MM39',
#  'A0A897NU04',
#  'A0A8F5H224',
#  'A0A8F5H224',
#  'A0A8H9IW98',
#  'A0A8J2Y9B9',
#  'A0A8J3C8B9',
#  'A4FQG6',
#  'B5Y6G0',
#  'C7RD60',
#  'C7RD64',
#  'C7RD65',
#  'C7RD76',
#  'C7RD77',
#  ...]

# %%
df['Entry1'] = entry_nueva

# %%
df
# Out:
#                                   Entry           sacc  qlen  slen  length  \
# 0                tr|B2CJ54|B2CJ54_9HYPO  Bifido1_01605   401   892     257
# 1                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     780
# 2                  sp|S0DL59|APF5_GIBF5  Bifido1_00288  1606  3110     210
# 3                  sp|S0DLN5|APF3_GIBF5  Bifido1_00708   295   266     276
# 4                 sp|S0DPY2|APF11_GIBF5  Bifido1_00712   562   683     325
# ...                                 ...            ...   ...   ...     ...
# 2024461  tr|A0A0L0LV25|A0A0L0LV25_BIFBR  Bifido1_00167   126   122     117
# 2024462  tr|A0A133KZQ8|A0A133KZQ8_BIFBR  Bifido1_00167   124   122     117
# 2024463  tr|A0A2K9AYJ9|A0A2K9AYJ9_BIFBR  Bifido1_00167   124   122     117
# 2024464          tr|V6XWB3|V6XWB3_BIFLN  Bifido1_00168   128   129     111
# 2024465          tr|W6EUJ5|W6EUJ5_BIFBR  Bifido1_00167   124   122     117
#
#          score  bitscore        evalue  pident  nident  mismatch  positive  \
# 0          143      59.7  7.690000e-11  27.237      70       163       114
# 1          880     343.0  7.790000e-97  31.282     244       469       370
# 2          270     108.0  1.500000e-24  34.762      73       126       102
# 3          142      59.3  2.090000e-11  26.087      72       177       120
# 4          197      80.5  5.120000e-17  22.769      74       220       141
# ...        ...       ...           ...     ...     ...       ...       ...
# 2024461    199      81.3  3.020000e-22  46.154      54        61        66
# 2024462    204      83.2  5.610000e-23  47.009      55        60        66
# 2024463    199      81.3  2.760000e-22  46.154      54        61        66
# 2024464    198      80.9  5.410000e-22  43.243      48        62        69
# 2024465    199      81.3  2.760000e-22  46.154      54        61        66
#
#          gaps  gapopen                                             stitle  \
# 0          24        7                                       Subtilisin E
# 1          67       16  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 2          11        2  Beta-ketoacyl-[acyl-carrier-protein] synthase ...
# 3          27        7                  Pyrroline-5-carboxylate reductase
# 4          31        6                      Multidrug export protein EmrB
# ...       ...      ...                                                ...
# 2024461     2        1                               hypothetical protein
# 2024462     2        1                               hypothetical protein
# 2024463     2        1                               hypothetical protein
# 2024464     1        1                               hypothetical protein
# 2024465     2        1                               hypothetical protein
#
#              Entry1
# 0            B2CJ54
# 1            S0DL59
# 2            S0DL59
# 3            S0DLN5
# 4            S0DPY2
# ...             ...
# 2024461  A0A0L0LV25
# 2024462  A0A133KZQ8
# 2024463  A0A2K9AYJ9
# 2024464      V6XWB3
# 2024465      W6EUJ5
#
# [2024466 rows x 16 columns]
